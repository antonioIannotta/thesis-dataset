# %%
import pandas as pd

# %%
data_dictionary = pd.read_csv('./Data_dictionary.csv')

# %%
data_dictionary[data_dictionary['Unnamed: 13'] == 'Yes']
# Out:
#      Unnamed: 0.1            Unnamed: 0                       Unnamed: 1  \
# 16             16             score_MAT                   Student scores
# 17             17             level_MAT                   Student scores
# 18             18             score_LEN                   Student scores
# 19             19             level_LEN                   Student scores
# 20             20             score_ING                   Student scores
# 21             21             level_ING                   Student scores
# 22             22                    a1            Student questionnaire
# 31             31                    a4            Student questionnaire
# 32             32              repeater            Student questionnaire
# 150           150                   a24            Student questionnaire
# 155           155                   a41            Student questionnaire
# 156           156                   a42            Student questionnaire
# ...
