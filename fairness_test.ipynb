# %%
import pandas as pd

# %%
columns_to_remove = [
    'Unnamed: 0',
    'id_student', 
    'id_student_original',
    'id_year',
    'id_grade',
    'id_class_group',
    'id_school',
    'id_student_16_19',
    'id_school_16_19',
    'student_questionnaire',
    'principals_questionnaire',
    'principals_questionnaire', 
    'teachers_questionnaire', 
    'census',
    'family_questionnaire'
]

# %%
dataset = pd.read_csv('./Dataset.csv')
# Out:
# C:\Users\anton\AppData\Local\Temp\ipykernel_12580\2158068584.py:1: DtypeWarning: Columns (172,173,391) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv('./Dataset.csv')

# %%
dataset = dataset.drop(columns=columns_to_remove)

# %%
data_dictionary = pd.read_csv('./Data_dictionary.csv')

# %%
data_dictionary
# Out:
#      Unnamed: 0.1           Unnamed: 0             Unnamed: 1   Unnamed: 2  \
# 0               0                  NaN                    NaN          NaN
# 1               1        Variable name                 Source         Type
# 2               2           id_student            Identifiers           ID
# 3               3  id_student_original            Identifiers           ID
# 4               4              id_year            Identifiers           ID
# ..            ...                  ...                    ...          ...
# 561           561                  pfc  Teacher questionnaire  Categorical
# 562           562                  rep  Teacher questionnaire  Categorical
# 563           563                  NaN                    NaN          NaN
# 564           564                  NaN                    NaN          NaN
# 565           565                  NaN                    NaN          NaN
#
# ...

# %%
categorical_attributes = data_dictionary[data_dictionary['Unnamed: 2'] == 'Categorical']

# %%
categorical_attributes['Unnamed: 0']
# Out:
# 17     level_MAT
# 19     level_LEN
# 21     level_ING
# 22            a1
# 23            a2
#          ...
# 558        p331f
# 559        p331g
# 560        p331j
# 561          pfc
# 562          rep
# Name: Unnamed: 0, Length: 465, dtype: object

# %%
for column in dataset.columns:
    if column in categorical_attributes['Unnamed: 0']:
        dataset[column].fillna(dataset[column].mode(), inplace=True)
# Out:
# scores
# score_MAT
# level_MAT
# score_LEN
# level_LEN
# score_ING
# level_ING
# a1
# a2
# a3a
# a3b
# living_with_father_mother
# a3c
# a3d
# a3et
# a3f
# a4
# repeater
# a5
# a6nm
# a7
# a8a
# a8b
# a8c
# a09a
# a09b
# a09c
# a09d
# a09e
# a9a
# a9b
# a9c
# a9d
# a9e
# a9f
# a9g
# a10a
# a10b
# a10c
# a10d
# a10e
# a10f
# a10g
# a10h
# a10i
# a10j
# a10k
# a10l
# a10m
# a10n
# a11a
# a11b
# a11c
# a11d
# a11e
# a11f
# a11g
# a11h
# a12a
# a12b
# a12c
# a12d
# a12e
# a12f
# a12g
# a12h
# a12i
# a13a
# a13b
# a13c
# a13d
# a13e
# a14a
# a14b
# a14c
# a14d
# a14e
# a14f
# a14g
# a14h
# a15a
# a15b
# a15c
# a15d
# a15e
# a15f
# a15g
# a15h
# a15i
# a15j
# a16a
# a16b
# a16c
# a16d
# a16e
# a16f
# a16g
# a16h
# a16i
# a16j
# a16k
# a16l
# a17a
# a17b
# a17c
# a17d
# a17e
# a17f
# a17g
# a17h
# a20a
# a20b
# a20c
# a20d
# a20e
# a21a
# a21b
# a21c
# a21d
# a21e
# a22a
# a22b
# a22c
# a22d
# a23a
# a23b
# a23c
# a23d
# a23e
# a23f
# a23g
# a23h
# a23i
# a23j
# a23k
# a24
# a40a
# a40b
# ...
